# %%
"""
By Keesari Vigneshwar Reddy
22UCC052
"""
print("Hello world")
# Out:
# Hello world

# %%
# reading the csv file with pandas library
# this file has header
import pandas as pd
df = pd.read_csv("50_Startups.csv")

# %%
# data frame
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
# display the first few rows of column
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
# print data types of all columns
df.dtypes
# all the data types belong to float which is quite relevant according to our data set
# Out:
# R&D Spend          float64
# Administration     float64
# Marketing Spend    float64
# State               object
# Profit             float64
# dtype: object

# %%
# Standard statistical data on numeric columns
df.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
"""
Dirty Data includes -> Incorrect names and typos, No consistent formatting, blank or null feilds
                       Duplicate rows,
"""
# Out:
# '\nDirty Data includes -> Incorrect names and typos, No consistent formatting, blank or null feilds\n                       Duplicate rows,\n'

# %%
# count of missing values in data frame
df.isnull().sum()
# we do not have any missing values or null values in our data frame
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
# count of duplicate values column wise
df.duplicated().sum()
# we do not have duplicate rows in our data frame
# Out:
# 0

# %%
df.tail()
# Out:
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 45    1000.23       124153.04          1903.93    New York  64926.08
# 46    1315.46       115816.21        297114.46     Florida  49490.75
# 47       0.00       135426.92             0.00  California  42559.73
# 48     542.05        51743.15             0.00    New York  35673.41
# 49       0.00       116983.80         45173.06  California  14681.40

# %%
"""
Now comes the part to remove irrelevant data
Assumption -> I believe that no startup could be scaled or established without R&D and Marketing Expenditure.
              So I am deleting the rows which where R&D Expenditure = 0
                                                           or
                                                    Marketing expenditure = 0
"""
# Out:
# '\nNow comes the part to remove irrelevant data\nAssumption -> I believe that no startup could be scaled or established without R&D and Marketing Expenditure.\n              So I am deleting the rows which where R&D Expenditure = 0\n                                                           or\n                                                    Marketing expenditure = 0\n'

# %%
df.drop(df[df['R&D Spend'] == 0].index, inplace=True)
df.drop(df[df['Marketing Spend'] == 0].index, inplace=True)

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
# Removing outliers data
numerical_columns = [i for i in df if df[i].dtype == 'float64']
# seaborn
import seaborn as sns
sns.swarmplot(data = pd.melt(df, value_vars = numerical_columns))
# Out:
# <Axes: >

# %%
"""
we have 3 distinct states in data frame 
it would be better to analyze the startups if we divide the data frame to 3 other data frames
since New york, Florida, California belong to different states in USA, some rules and perspectives are dependent on place to place
For a good data analysis, it is better to create 3 other data frames
"""
pd.Categorical(df['State'])
# Out:
# ['New York', 'California', 'Florida', 'New York', 'Florida', ..., 'California', 'New York', 'California', 'New York', 'Florida']
# Length: 46
# Categories (3, object): ['California', 'Florida', 'New York']

# %%
df1 = df[df['State'] == 'New York']
df1 = df1.reset_index()
df1
# Now we have new indices and indices in original data frame
# Out:
#     index  R&D Spend  Administration  Marketing Spend     State     Profit
# 0       0  165349.20       136897.80        471784.10  New York  192261.83
# 1       3  144372.41       118671.85        383199.62  New York  182901.99
# 2       5  131876.90        99814.71        362861.36  New York  156991.12
# 3       8  120542.52       148718.95        311613.29  New York  152211.77
# 4      15  114523.61       122616.84        261776.23  New York  129917.04
# 5      17   94657.16       145077.58        282574.31  New York  125370.37
# 6      21   78389.47       153773.43        299737.29  New York  111313.02
# 7      24   77044.01        99281.34        140574.81  New York  108552.04
# 8      27   72107.60       127864.55        353183.81  New York  105008.31
# 9      29   65605.48       153032.06        107138.38  New York  101004.64
# 10     31   61136.38       152701.92         88218.23  New York   97483.56
# ...

# %%
df2 = df[df['State'] == 'California']
df2 = df2.reset_index()
df2
# Now we have new indices and indices in original data frame
# Out:
#     index  R&D Spend  Administration  Marketing Spend       State     Profit
# 0       1  162597.70       151377.59        443898.53  California  191792.06
# 1       6  134615.46       147198.87        127716.82  California  156122.51
# 2       9  123334.88       108679.17        304981.62  California  149759.96
# 3      11  100671.96        91790.61        249744.55  California  144259.40
# 4      13   91992.39       135495.07        252664.93  California  134307.35
# 5      16   78013.11       121597.55        264346.06  California  126992.93
# 6      20   76253.86       113867.30        298664.47  California  118474.03
# 7      25   64664.71       139553.16        137962.62  California  107404.34
# 8      32   63408.86       129219.61         46085.25  California   97427.84
# 9      34   46426.07       157693.92        210797.67  California   96712.80
# 10     37   44069.95        51283.14        197029.42  California   89949.14
# ...

# %%
df3 = df[df['State'] == 'Florida']
df3 = df3.reset_index()
df3
# Now we have new indices and indices in original data frame
# Out:
#     index  R&D Spend  Administration  Marketing Spend    State     Profit
# 0       2  153441.51       101145.55        407934.54  Florida  191050.39
# 1       4  142107.34        91391.77        366168.42  Florida  166187.94
# 2       7  130298.13       145530.06        323876.68  Florida  155752.60
# 3      10  101913.08       110594.11        229160.95  Florida  146121.95
# 4      12   93863.75       127320.38        249839.44  Florida  141585.52
# 5      14  119943.24       156547.42        256512.92  Florida  132602.65
# 6      18   91749.16       114175.79        294919.57  Florida  124266.90
# 7      22   73994.56       122782.75        303319.26  Florida  110352.25
# 8      23   67532.53       105751.03        304768.73  Florida  108733.99
# 9      26   75328.87       144135.98        134050.07  Florida  105733.54
# 10     28   66051.52       182645.56        118148.20  Florida  103282.38
# 11     30   61994.48       115641.28         91131.24  Florida   99937.59
# ...

# %%
"""
There is no need to standardize capitalization since everything is perfect.
Formatting of data set is also perfect.
We can also sort the data frame with respect to numeric aspects on the basis of our requirement
"""
# Out:
# '\nThere is no need to standardize capitalization since everything is perfect.\nFormatting of data set is also perfect.\nWe can also sort the data frame with respect to numeric aspects on the basis of our requirement\n'

# %%
# sorting on the basis of R&D Spend
df.sort_values('R&D Spend')
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 45    1000.23       124153.04          1903.93    New York   64926.08
# 46    1315.46       115816.21        297114.46     Florida   49490.75
# 43   15505.73       127382.30         35534.17    New York   69758.98
# 38   20229.59        65947.93        185265.10    New York   81229.06
# 44   22177.74       154806.14         28334.72  California   65200.33
# 42   23640.93        96189.63        148001.11  California   71498.49
# 41   27892.92        84710.77        164470.71     Florida   77798.83
# 36   28663.76       127056.21        201126.82     Florida   90708.19
# 40   28754.33       118546.05        172795.67  California   78239.91
# 39   38558.51        82982.09        174999.30  California   81005.76
# 37   44069.95        51283.14        197029.42  California   89949.14
# 35   46014.02        85047.44        205517.64    New York   96479.51
# ...

# %%
# sorting on the basis of Administration
df.sort_values('Administration')
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 37   44069.95        51283.14        197029.42  California   89949.14
# 38   20229.59        65947.93        185265.10    New York   81229.06
# 39   38558.51        82982.09        174999.30  California   81005.76
# 41   27892.92        84710.77        164470.71     Florida   77798.83
# 35   46014.02        85047.44        205517.64    New York   96479.51
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 11  100671.96        91790.61        249744.55  California  144259.40
# 42   23640.93        96189.63        148001.11  California   71498.49
# 24   77044.01        99281.34        140574.81    New York  108552.04
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 33   55493.95       103057.49        214634.81     Florida   96778.92
# ...

# %%
# sorting on the basis of Marketing Spend
df.sort_values('Marketing Spend')
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 45    1000.23       124153.04          1903.93    New York   64926.08
# 44   22177.74       154806.14         28334.72  California   65200.33
# 43   15505.73       127382.30         35534.17    New York   69758.98
# 32   63408.86       129219.61         46085.25  California   97427.84
# 31   61136.38       152701.92         88218.23    New York   97483.56
# 30   61994.48       115641.28         91131.24     Florida   99937.59
# 29   65605.48       153032.06        107138.38    New York  101004.64
# 28   66051.52       182645.56        118148.20     Florida  103282.38
# 6   134615.46       147198.87        127716.82  California  156122.51
# 26   75328.87       144135.98        134050.07     Florida  105733.54
# 25   64664.71       139553.16        137962.62  California  107404.34
# 24   77044.01        99281.34        140574.81    New York  108552.04
# ...

# %%
"""
And we can do many operations on the basis of our requirement
"""
# Out:
# '\nAnd we can do many operations on the basis of our requirement\n'

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
# Or there can be another way instead of creating 3 other data frames
# using label encoder we can convert categorical values to numerical values 
label_encoder = LabelEncoder()
df['State'] = label_encoder.fit_transform(df['State'])
df
# Out:
#     R&D Spend  Administration  Marketing Spend  State     Profit
# 0   165349.20       136897.80        471784.10      2  192261.83
# 1   162597.70       151377.59        443898.53      0  191792.06
# 2   153441.51       101145.55        407934.54      1  191050.39
# 3   144372.41       118671.85        383199.62      2  182901.99
# 4   142107.34        91391.77        366168.42      1  166187.94
# 5   131876.90        99814.71        362861.36      2  156991.12
# 6   134615.46       147198.87        127716.82      0  156122.51
# 7   130298.13       145530.06        323876.68      1  155752.60
# 8   120542.52       148718.95        311613.29      2  152211.77
# 9   123334.88       108679.17        304981.62      0  149759.96
# 10  101913.08       110594.11        229160.95      1  146121.95
# 11  100671.96        91790.61        249744.55      0  144259.40
# 12   93863.75       127320.38        249839.44      1  141585.52
# ...

# %%
# sorting them on the basis of state
df.sort_values("State")
# Out:
#     R&D Spend  Administration  Marketing Spend  State     Profit
# 25   64664.71       139553.16        137962.62      0  107404.34
# 13   91992.39       135495.07        252664.93      0  134307.35
# 34   46426.07       157693.92        210797.67      0   96712.80
# 11  100671.96        91790.61        249744.55      0  144259.40
# 9   123334.88       108679.17        304981.62      0  149759.96
# 32   63408.86       129219.61         46085.25      0   97427.84
# 39   38558.51        82982.09        174999.30      0   81005.76
# 37   44069.95        51283.14        197029.42      0   89949.14
# 40   28754.33       118546.05        172795.67      0   78239.91
# 20   76253.86       113867.30        298664.47      0  118474.03
# 42   23640.93        96189.63        148001.11      0   71498.49
# 44   22177.74       154806.14         28334.72      0   65200.33
# 1   162597.70       151377.59        443898.53      0  191792.06
# ...

# %%
"""
Our data is ready for implementing a learning algorithm
"""
# Out:
# '\nOur data is ready for implementing a learning algorithm\n'

# %% [markdown]
# # Logistic Regression as an example

# %%
"""
making x array which contains all the 4 values -> R&D Spend	
                                                  Administration
                                                  Marketing Spend
                                                  Profit
"""
# Creating a numpy array of data frame
x = df[["R&D Spend", "Administration", "Marketing Spend", "Profit"]].values
x
# Out:
# array([[165349.2 , 136897.8 , 471784.1 , 192261.83],
#        [162597.7 , 151377.59, 443898.53, 191792.06],
#        [153441.51, 101145.55, 407934.54, 191050.39],
#        [144372.41, 118671.85, 383199.62, 182901.99],
#        [142107.34,  91391.77, 366168.42, 166187.94],
#        [131876.9 ,  99814.71, 362861.36, 156991.12],
#        [134615.46, 147198.87, 127716.82, 156122.51],
#        [130298.13, 145530.06, 323876.68, 155752.6 ],
#        [120542.52, 148718.95, 311613.29, 152211.77],
#        [123334.88, 108679.17, 304981.62, 149759.96],
#        [101913.08, 110594.11, 229160.95, 146121.95],
#        [100671.96,  91790.61, 249744.55, 144259.4 ],
#        [ 93863.75, 127320.38, 249839.44, 141585.52],
#        [ 91992.39, 135495.07, 252664.93, 134307.35],
#        [119943.24, 156547.42, 256512.92, 132602.65],
#        [114523.61, 122616.84, 261776.23, 129917.04],
#        [ 78013.11, 121597.55, 264346.06, 126992.93],
#        [ 94657.16, 145077.58, 282574.31, 125370.37],
# ...

# %%
# second array
y = df["State"].values
y
# Out:
# array([2, 0, 1, 2, 1, 2, 0, 1, 2, 0, 1, 0, 1, 0, 1, 2, 0, 2, 1, 0, 2, 1,
#        1, 2, 0, 1, 2, 1, 2, 1, 2, 0, 1, 0, 2, 1, 0, 2, 0, 0, 1, 0, 2, 0,
#        2, 1])

# %%
# since this is supervised learning we are to split data into train and test
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)
# In our whole data 20% is test data and 80% is train data

# %%
# Algorithm 1 -> Logistic regression
from sklearn.linear_model import LogisticRegression
logmodel = LogisticRegression()
logmodel.fit(x_train, y_train)
# we have fitted the training model on train_data
# Out:
# LogisticRegression()

# %%
# prediction
y_pred = logmodel.predict(x_test)
print(y_pred)
print(y_test)
# Out:
# [2 2 2 2 2 2 2 1 2 2]
# [0 0 1 0 1 1 1 0 1 2]

# %%
# confusion matrix
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[0, 1, 3],
#        [0, 0, 5],
#        [0, 0, 1]])

# %%
#accuracy
(0 + 0 + 1) / (0 + 1 + 3 + 0 + 0 + 5 + 0 + 0 + 1)
# Out:
# 0.1

# %%
"""
In this way we made our data frame to implement a machine learning model. Simply to say "We have preprocessed the data"
We can perform other algorithms also for better accuracy
"""
# Out:
# '\nIn this way we made our data frame to implement a machine learning model. Simply to say "We have preprocessed the data"\nWe can perform other algorithms also for better accuracy\n'

# %% [markdown]
# # Implementing Support Vector Machine with Linear Kernel

# %%
# linear kernel
from sklearn.svm import SVC
classifier_svm_linear = SVC(kernel='linear')
classifier_svm_linear.fit(x_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
# prediction
y_pred = classifier_svm_linear.predict(x_test)
# confusion matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[0, 1, 3],
#        [0, 0, 5],
#        [0, 0, 1]])

# %%
# final data frame
df
# Out:
#     R&D Spend  Administration  Marketing Spend  State     Profit
# 0   165349.20       136897.80        471784.10      2  192261.83
# 1   162597.70       151377.59        443898.53      0  191792.06
# 2   153441.51       101145.55        407934.54      1  191050.39
# 3   144372.41       118671.85        383199.62      2  182901.99
# 4   142107.34        91391.77        366168.42      1  166187.94
# 5   131876.90        99814.71        362861.36      2  156991.12
# 6   134615.46       147198.87        127716.82      0  156122.51
# 7   130298.13       145530.06        323876.68      1  155752.60
# 8   120542.52       148718.95        311613.29      2  152211.77
# 9   123334.88       108679.17        304981.62      0  149759.96
# 10  101913.08       110594.11        229160.95      1  146121.95
# 11  100671.96        91790.61        249744.55      0  144259.40
# 12   93863.75       127320.38        249839.44      1  141585.52
# ...

# %%
final = df
final.to_csv("Final_Data_cleaned_Copy.csv")
